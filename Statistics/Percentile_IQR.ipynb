# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
State=['Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware']
Population=[4779736,710231,6392017,2915918,37253956,5029196,3574097,897934]
Murder_rate=[5.7,5.6,4.7,5.6,4.4,2.8,2.4,5.8]
Abbreviation=['AL','AK','AZ','AR','CA','CO','CT','DE']
di={'State':State,'Population':Population,'Murder_rate':Murder_rate,'Abbreviation':Abbreviation}
state=pd.DataFrame(di)

# %%
state
# Out:
#          State  Population  Murder_rate Abbreviation
# 0      Alabama     4779736          5.7           AL
# 1       Alaska      710231          5.6           AK
# 2      Arizona     6392017          4.7           AZ
# 3     Arkansas     2915918          5.6           AR
# 4   California    37253956          4.4           CA
# 5     Colorado     5029196          2.8           CO
# 6  Connecticut     3574097          2.4           CT
# 7     Delaware      897934          5.8           DE

# %%
state['Population'].mean()          # Average
# Out:
# 7694135.625

# %%
state['Population'].median()         # Middle value after sorting
# Out:
# 4176916.5

# %%
state['Population'].mode()            # Most occured value
# Out:
# 0      710231
# 1      897934
# 2     2915918
# 3     3574097
# 4     4779736
# 5     5029196
# 6     6392017
# 7    37253956
# Name: Population, dtype: int64

# %% [markdown]
# as all are unique so all 7

# %%
print(state['Population'].std())
print(state['Population'].quantile(0.75))
# Out:
# 12105745.29585633
# 5369901.25

# %%
state.describe()
# Out:
#          Population  Murder_rate
# count  8.000000e+00     8.000000
# mean   7.694136e+06     4.625000
# std    1.210575e+07     1.350926
# min    7.102310e+05     2.400000
# 25%    2.411422e+06     4.000000
# 50%    4.176916e+06     5.150000
# 75%    5.369901e+06     5.625000
# max    3.725396e+07     5.800000

# %%
print(state['Murder_rate'].quantile([0.05,0.25,0.50,0.75,0.95]),state['Population'].quantile([0.05,0.25,0.50,0.75,0.95]),sep='\n')

# => x% let 75% values are below this value
# Out:
# 0.05    2.540
# 0.25    4.000
# 0.50    5.150
# 0.75    5.625
# 0.95    5.765
# Name: Murder_rate, dtype: float64
# 0.05      775927.05
# 0.25     2411422.00
# 0.50     4176916.50
# 0.75     5369901.25
# 0.95    26452277.35
# Name: Population, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
state.hist(bins=50)
plt.show()

# %%
state.boxplot('Murder_rate')
plt.show()

# %%
sns.boxplot(state['Murder_rate'])
plt.show()

# %%
sns.boxplot(state["Population"])
plt.show()

# %%
x=np.linspace(0,10,100,)
fig=plt.figure()
plt.plot(x,np.sin(x),'.')
plt.plot(x,np.cos(x),'--')
plt.show()

# %%
print(x)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...
