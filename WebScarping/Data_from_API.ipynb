# %% [markdown]
# Fetching Top movies data from TMDB website (TMDB API)

# %%
import pandas as pd
import requests 
import warnings
warnings.filterwarnings('ignore')

# using requests we will create an HTTP req in python
# HTTP - protocol to access web page data

# %% [markdown]
# - https://api.themoviedb.org/3/movie/top_rated?api_key=73feb80678b534b19176579a313ff8ba&language=en-US&page=1
#
# - 73feb80678b534b19176579a313 is my API key (which i entered)
# - US&page=1 means the first page of the website's topmovies results (we used the top movies API there are many more APIs eg.. worst movies)

# %%
# response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=73feb80678b534b19176579a313ff8ba&language=en-US&page=1")

# %%
df=pd.DataFrame(response.json()['results'])
# json is a dictionary in which we selected results 'key' 
df2=pd.DataFrame(response.json()['results'])[["id","genre_ids","original_language","title","adult","popularity","release_date","vote_average","vote_count"]] 
# to directly import only desired columns to dataframe

# %% [markdown]
# - we selected results b/c that's what we need
# - then in results we selected the columns we need

# %%
df.head(2)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg  [18, 80]  238                en
# 1  False  /wPU78OPN4BYEgWYdXyg0phMee64.jpg  [18, 80]  278                en
#
#              original_title  \
# 0             The Godfather
# 1  The Shawshank Redemption
#
#                                             overview  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...     117.912
# 1  Framed in the 1940s for the double murder of h...      97.494
#
#                         poster_path release_date                     title  \
# 0  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
# 1  /hBcY0fE9pfXzvVaY4GKarweriG2.jpg   1994-09-23  The Shawshank Redemption
#
#    video  vote_average  vote_count
# 0  False           8.7       17593
# 1  False           8.7       23432

# %%
df2.head(5)
# Out:
#        id            genre_ids original_language  \
# 0     238             [18, 80]                en
# 1     278             [18, 80]                en
# 2  772071             [35, 14]                es
# 3  995133  [16, 10751, 12, 14]                en
# 4     240             [18, 80]                en
#
#                                       title  adult  popularity release_date  \
# 0                             The Godfather  False     117.912   1972-03-14
# 1                  The Shawshank Redemption  False      97.494   1994-09-23
# 2                          Cuando Sea Joven  False      50.035   2022-09-14
# 3  The Boy, the Mole, the Fox and the Horse  False      59.921   2022-12-25
# 4                     The Godfather Part II  False      65.399   1974-12-20
#
#    vote_average  vote_count
# 0           8.7       17593
# 1           8.7       23432
# 2           8.7         211
# 3           8.6         260
# 4           8.6       10654

# %%
dfmerged=pd.DataFrame()

# %%
dfmerged
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,490):
    response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=73feb80678b534b19176579a313ff8ba&language=en-US&page={}".format(i))
    temp_df=pd.DataFrame(response.json()['results'])[["id","genre_ids","original_language","title","adult","popularity","release_date","vote_average","vote_count"]] 
    dfmerged=dfmerged.append(temp_df,ignore_index=True)

# %% [markdown]
# - as in each pg 20 results so the 2nd loop will hv again 1-20 index not 21,22...
# - as there are lot oof pages so it will take some time to execute

# %%
dfmerged
# Out:
#            id            genre_ids original_language  \
# 0         238             [18, 80]                en
# 1         278             [18, 80]                en
# 2      772071             [35, 14]                es
# 3      995133  [16, 10751, 12, 14]                en
# 4         240             [18, 80]                en
# ...       ...                  ...               ...
# 20675  466622             [28, 53]                en
# 20676    9586         [80, 35, 18]                en
# 20677   23742         [28, 35, 80]                en
# 20678    6171    [18, 27, 878, 53]                en
# 20679  298722                 [35]                it
#
#                                           title  adult  popularity  \
# 0                                 The Godfather  False     117.912
# 1                      The Shawshank Redemption  False      97.494
# 2                              Cuando Sea Joven  False      50.035
# ...

# %%
dfmerged.shape
# Out:
# (20680, 9)

# %% [markdown]
# #### convertinvg the dataframe to a csv file and storing it locally

# %%
# dfmerged.to_csv("topmovies.csv")

# %% [markdown]
# - topmovies.csv was created here transported to Datasets
# - now can upload this dataset to kaggle
# - it will increase credibility

# %% [markdown]
# Go to Rapid api We'll get free API's list there and we can create our own datasets using it
