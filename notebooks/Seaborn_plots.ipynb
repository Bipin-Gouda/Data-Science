# %% [markdown]
# # Seaborn

# %% [markdown]
# ## Distribution plots
#
#   - Distplot
#   - Jointplot
#   - Pairplot
#   - Heatmap
#   - Scatterplot

# %% [markdown]
# ## Categorical plots
#
#    - boxplot
#    - violinplot
#    - countplot
#    - barplot

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df               # tip = dependent feature
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# # Distribution Plots

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %% [markdown]
# ## Scatter plot / Regression plot

# %%
sns.regplot(data=df,x='tip',y='total_bill')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot()
# Out:
# <Axes: >

# %% [markdown]
# ## Joint Plot

# %% [markdown]
# A jointplot allows to study the numerical relationship between 2 numeric variables. The central chart displays the correlation. It is usually a scatterplot, a hexbin plot, a 2D histogram or a 2D density plot

# %%
sns.jointplot(data=df,x=df['tip'],y=df['total_bill'],kind='hex')

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='size')

# %% [markdown]
# # ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ #

# %% [markdown]
#      PLOTTING USING :    df['Categorical_var'].value_counts().plot()  to get countplot

# %%
import pandas as pd
df['smoker'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
#     PLOTTING USING :      plt.bar()  to get countplot

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
lst=['No','Yes']
plt.bar(lst,df['smoker'].value_counts())    #  (x,y) height is y parameter of bar plot with which it plots
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ #

# %%
sns.pairplot(df,hue='smoker')

# %% [markdown]
# ## Histogram / Distplot

# %% [markdown]
#     Y axis of histogram represents frequency    TF: it's value may change w.r.t bins
#
#     ... distplot helps us to check the distribution

# %%
sns.histplot(df['tip'],kde=True)         # bins = no of bars
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# * Left skewed

# %%
sns.histplot(df['tip'],kde=True,bins=4)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# * Left skewed

# %%
sns.histplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# #  Plots For Categorical Variables

# %% [markdown]
# ## Categorical plots
#
#    - boxplot
#    - violinplot
#    - countplot
#    - barplot

# %%
sns.countplot(x=df['sex'],hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x=df['smoker'],y=df['tip'],hue=df['day'])
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
fig = plt.gcf()
fig.set_size_inches(5, 3)
sns.boxplot(x=df['smoker'],y=df['tip'])
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>
