# %% [markdown]
# Inserting images in markdown and python cells

# %%
from IPython.display import Image
Image(filename ="E:\Data Science\Img.jpg", width=600, height=100)

# %% [markdown]
# For entering in markdown and setting height and width
# <img src="../Img.jpg" alt= “” width="700" height="400">

# %% [raw]
# <img src="../Img.jpg" alt= “” width="700" height="400">
